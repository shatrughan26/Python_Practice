# %%
import pandas as pd
df = pd.read_csv("Insurance_Data.csv")
df.head()
# Out:
#    age  have_insuance
# 0   22              0
# 1   25              0
# 2   47              1
# 3   52              0
# 4   46              1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['age'],df['have_insuance'],marker='+',color = 'red')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.have_insuance, test_size=0.1)

# %%
len(x_train)
# Out:
# 24

# %%
len(x_test)
# Out:
# 3

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 22   40
# 9    61
# 12   27

# %%
model.predict(x_test)
# Out:
# array([1, 1, 0], dtype=int64)

# %%
model.predict([[55]])
# Out:
# c:\Users\Deepak\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.49183137, 0.50816863],
#        [0.06010724, 0.93989276],
#        [0.83878953, 0.16121047]])

# %%
model.score(x_test,y_test)
# Out:
# 1.0
